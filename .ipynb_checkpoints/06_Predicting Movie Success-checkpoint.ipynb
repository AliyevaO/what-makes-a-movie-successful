# %% [markdown]
# # Linear Regression
# For part 5 of the project, I will be applying my Linear Regression knowledge to create a Linear Regression model that meets the 4 assumptions of Linear Regression.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats

import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.compose import make_column_transformer, make_column_selector, ColumnTransformer
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
## fixing random for lesson generation
np.random.seed(321)

# %%
#load data
df = pd.read_csv('Data/tmdb_results_combined.csv.gz',lineterminator="\n")
df
# Out:
#          imdb_id  adult                     backdrop_path  \
# 0      tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 1      tt0113092    0.0                               NaN
# 2      tt0116391    0.0                               NaN
# 3      tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# 4      tt0118852    0.0                               NaN
# ...          ...    ...                               ...
# 64987  tt9895024    0.0   /S1kutYyoyuBJKGS0mXxv2fZNbr.jpg
# 64988  tt9896876    0.0  /hMvRbT6HOqERhh3K8kXbaLz9LlZ.jpg
# 64989  tt9898844    0.0  /q2KFBGyUSzHDhNqXEYv2LqTWVSz.jpg
# 64990  tt9900940    0.0  /3jjWLg5bevWqReyVroYqxwVrH0k.jpg
# 64991  tt9907782    0.0  /gRTYArznK1MLAq7opC1tYHnTwM3.jpg
#
#       belongs_to_collection      budget  \
# 0                       NaN  10000000.0
# 1                       NaN         0.0
# 2                       NaN         0.0
# 3                       NaN    150000.0
# 4                       NaN         0.0
# ...                     ...         ...
# 64987                   NaN         0.0
# 64988                   NaN         0.0
# 64989                   NaN         0.0
# 64990                   NaN         0.0
# 64991                   NaN         0.0
#
#                                                   genres  \
# 0      [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 1               [{'id': 878, 'name': 'Science Fiction'}]
# 2      [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 3      [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 4                          [{'id': 18, 'name': 'Drama'}]
# ...                                                  ...
# 64987  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 64988  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 64989                     [{'id': 27, 'name': 'Horror'}]
# 64990  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 64991  [{'id': 27, 'name': 'Horror'}, {'id': 14, 'nam...
#
#                                    homepage        id original_language  \
# 0                                       NaN   62127.0                en
# 1                                       NaN  110977.0                en
# 2                                       NaN  442869.0                hi
# 3      http://www.wkw-inthemoodforlove.com/     843.0                cn
# 4                                       NaN   49511.0                en
# ...                                     ...       ...               ...
# 64987                                   NaN  834443.0                de
# 64988                                   NaN  821493.0                en
# 64989                                   NaN  870671.0                en
# 64990                                   NaN  861294.0                en
# 64991                                   NaN  630392.0                en
#
#                 original_title  ...     revenue  runtime  \
# 0              The Fantasticks  ...         0.0     86.0
# 1                For the Cause  ...         0.0    100.0
# 2                         Gang  ...         0.0    152.0
# 3                         花樣年華  ...  12854953.0     99.0
# 4               Chinese Coffee  ...         0.0     99.0
# ...                        ...  ...         ...      ...
# 64987              Heikos Welt  ...         0.0    118.0
# 64988  India Sweets and Spices  ...         0.0    101.0
# 64989              The Hunting  ...         0.0     91.0
# 64990             The Scrapper  ...         0.0     87.0
# 64991               The Cursed  ...   4588389.0    111.0
#
#                                         spoken_languages    status  \
# 0      [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1      [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2      [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 3      [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# 4      [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# ...                                                  ...       ...
# 64987  [{'english_name': 'German', 'iso_639_1': 'de',...  Released
# 64988  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 64989  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 64990  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 64991  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                                  tagline  \
# 0          Try to remember the first time magic happened
# 1           The ultimate showdown on a forbidden planet.
# 2                                                    NaN
# 3      Feel the heat, keep the feeling burning, let t...
# 4      There's a fine line between friendship and bet...
# ...                                                  ...
# 64987                                                NaN
# 64988                              Let the aunties talk.
# 64989                                  Hunger runs deep.
# 64990                        You can't escape your past.
# 64991                                                NaN
#
#                          title  video  vote_average vote_count certification
# 0              The Fantasticks    0.0           5.4       21.0           NaN
# 1                For the Cause    0.0           4.4        7.0           NaN
# 2                         Gang    0.0           0.0        0.0           NaN
# 3         In the Mood for Love    0.0           8.1     1859.0            PG
# 4               Chinese Coffee    0.0           6.9       45.0             R
# ...                        ...    ...           ...        ...           ...
# 64987            Heiko's World    0.0           0.0        0.0           NaN
# 64988  India Sweets and Spices    0.0           6.0        2.0         PG-13
# 64989              The Hunting    0.0           4.9       20.0           NaN
# 64990             The Scrapper    0.0           6.0        2.0           NaN
# 64991               The Cursed    0.0           7.0       55.0             R
#
# [64992 rows x 26 columns]

# %%
#remove ids that are 0  and then reset index
df = df[df['imdb_id'] != '0']
df
# Out:
#          imdb_id  adult                     backdrop_path  \
# 0      tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 1      tt0113092    0.0                               NaN
# 2      tt0116391    0.0                               NaN
# 3      tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# 4      tt0118852    0.0                               NaN
# ...          ...    ...                               ...
# 64987  tt9895024    0.0   /S1kutYyoyuBJKGS0mXxv2fZNbr.jpg
# 64988  tt9896876    0.0  /hMvRbT6HOqERhh3K8kXbaLz9LlZ.jpg
# 64989  tt9898844    0.0  /q2KFBGyUSzHDhNqXEYv2LqTWVSz.jpg
# 64990  tt9900940    0.0  /3jjWLg5bevWqReyVroYqxwVrH0k.jpg
# 64991  tt9907782    0.0  /gRTYArznK1MLAq7opC1tYHnTwM3.jpg
#
#       belongs_to_collection      budget  \
# 0                       NaN  10000000.0
# 1                       NaN         0.0
# 2                       NaN         0.0
# 3                       NaN    150000.0
# 4                       NaN         0.0
# ...                     ...         ...
# 64987                   NaN         0.0
# 64988                   NaN         0.0
# 64989                   NaN         0.0
# 64990                   NaN         0.0
# 64991                   NaN         0.0
#
#                                                   genres  \
# 0      [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 1               [{'id': 878, 'name': 'Science Fiction'}]
# 2      [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 3      [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 4                          [{'id': 18, 'name': 'Drama'}]
# ...                                                  ...
# 64987  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 64988  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 64989                     [{'id': 27, 'name': 'Horror'}]
# 64990  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 64991  [{'id': 27, 'name': 'Horror'}, {'id': 14, 'nam...
#
#                                    homepage        id original_language  \
# 0                                       NaN   62127.0                en
# 1                                       NaN  110977.0                en
# 2                                       NaN  442869.0                hi
# 3      http://www.wkw-inthemoodforlove.com/     843.0                cn
# 4                                       NaN   49511.0                en
# ...                                     ...       ...               ...
# 64987                                   NaN  834443.0                de
# 64988                                   NaN  821493.0                en
# 64989                                   NaN  870671.0                en
# 64990                                   NaN  861294.0                en
# 64991                                   NaN  630392.0                en
#
#                 original_title  ...     revenue  runtime  \
# 0              The Fantasticks  ...         0.0     86.0
# 1                For the Cause  ...         0.0    100.0
# 2                         Gang  ...         0.0    152.0
# 3                         花樣年華  ...  12854953.0     99.0
# 4               Chinese Coffee  ...         0.0     99.0
# ...                        ...  ...         ...      ...
# 64987              Heikos Welt  ...         0.0    118.0
# 64988  India Sweets and Spices  ...         0.0    101.0
# 64989              The Hunting  ...         0.0     91.0
# 64990             The Scrapper  ...         0.0     87.0
# 64991               The Cursed  ...   4588389.0    111.0
#
#                                         spoken_languages    status  \
# 0      [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1      [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2      [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 3      [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# 4      [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# ...                                                  ...       ...
# 64987  [{'english_name': 'German', 'iso_639_1': 'de',...  Released
# 64988  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 64989  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 64990  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 64991  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                                  tagline  \
# 0          Try to remember the first time magic happened
# 1           The ultimate showdown on a forbidden planet.
# 2                                                    NaN
# 3      Feel the heat, keep the feeling burning, let t...
# 4      There's a fine line between friendship and bet...
# ...                                                  ...
# 64987                                                NaN
# 64988                              Let the aunties talk.
# 64989                                  Hunger runs deep.
# 64990                        You can't escape your past.
# 64991                                                NaN
#
#                          title  video  vote_average vote_count certification
# 0              The Fantasticks    0.0           5.4       21.0           NaN
# 1                For the Cause    0.0           4.4        7.0           NaN
# 2                         Gang    0.0           0.0        0.0           NaN
# 3         In the Mood for Love    0.0           8.1     1859.0            PG
# 4               Chinese Coffee    0.0           6.9       45.0             R
# ...                        ...    ...           ...        ...           ...
# 64987            Heiko's World    0.0           0.0        0.0           NaN
# 64988  India Sweets and Spices    0.0           6.0        2.0         PG-13
# 64989              The Hunting    0.0           4.9       20.0           NaN
# 64990             The Scrapper    0.0           6.0        2.0           NaN
# 64991               The Cursed    0.0           7.0       55.0             R
#
# [64968 rows x 26 columns]

# %% [markdown]
# ## Feature Engineering
# * Collection: convert to boolean
# * Genres: get just name and OHE
# * Cleaning Certification
# * Converting release date to year, month, and day.

# %%
## Columns to exclude - Keeping Status and companies
drop_cols = ['backdrop_path','backdrop_path','original_title','overview',
                 'poster_path','tagline','id','homepage', #'status','production_companies'
                 'production_countries','video','spoken_languages',
            'original_language']
df = df.drop(columns=drop_cols)

## Use .notna() to get True if it belongs to a collection
df['belongs_to_collection'] = df['belongs_to_collection'].notna()

## Function to get just the genre names as a list 
import json
def get_genre_name(x):
    x = x.replace("'",'"')
    x = json.loads(x)
    
    genres = []
    for genre in x:
        genres.append(genre['name'])
    return genres

## Use ourn function and exploding the new column
df['genres_list'] = df['genres'].apply(get_genre_name)
df_explode = df.explode('genres_list')

## save unique genres
unique_genres = df_explode['genres_list'].dropna().unique()

## Manually One-Hot-Encode Genres
for genre in unique_genres:
    df[f"Genre_{genre}"] = df['genres'].str.contains(genre,regex=False)    


## Drop original genre cols
df = df.drop(columns=['genres','genres_list'])


#### Fixing Certification
## Checking Certification values
df['certification'].value_counts(dropna=False)
# fix extra space certs
df['certification'] = df['certification'].str.strip()

## fix certification col
repl_cert = {'UR':'NR',
             'Not Rated':'NR',
             'Unrated':'NR',
             '-':'NR',
             '10':np.nan,
             'ScreamFest Horror Film Festival':'NR'}
df['certification'] = df['certification'].replace(repl_cert)
df['certification'].value_counts(dropna=False)


#### Converting year to sep features
## split release date into 3 columns
new_cols = ['year','month','day']
df[new_cols] = df['release_date'].str.split('-',expand=True)
df[new_cols] = df[new_cols].astype(float)

## drop original feature
df = df.drop(columns=['release_date'])
df
# Out:
#          imdb_id  adult  belongs_to_collection      budget  popularity  \
# 0      tt0113026    0.0                  False  10000000.0       2.615
# 1      tt0113092    0.0                  False         0.0       1.993
# 2      tt0116391    0.0                  False         0.0       0.676
# 3      tt0118694    0.0                  False    150000.0      20.312
# 4      tt0118852    0.0                  False         0.0       5.350
# ...          ...    ...                    ...         ...         ...
# 64987  tt9895024    0.0                  False         0.0       0.688
# 64988  tt9896876    0.0                  False         0.0       4.490
# 64989  tt9898844    0.0                  False         0.0     472.600
# 64990  tt9900940    0.0                  False         0.0       2.727
# 64991  tt9907782    0.0                  False         0.0      35.350
#
#                                     production_companies     revenue  runtime  \
# 0      [{'id': 51207, 'logo_path': None, 'name': 'Sul...         0.0     86.0
# 1      [{'id': 7405, 'logo_path': '/rfnws0uY8rsNAsrLb...         0.0    100.0
# 2                                                     []         0.0    152.0
# 3      [{'id': 539, 'logo_path': None, 'name': 'Block...  12854953.0     99.0
# 4      [{'id': 67930, 'logo_path': None, 'name': 'Cha...         0.0     99.0
# ...                                                  ...         ...      ...
# 64987  [{'id': 154995, 'logo_path': None, 'name': 'AS...         0.0    118.0
# 64988  [{'id': 737, 'logo_path': '/dK1GZ1u4our8sJW0St...         0.0    101.0
# 64989  [{'id': 160303, 'logo_path': None, 'name': 'Mo...         0.0     91.0
# 64990  [{'id': 91999, 'logo_path': None, 'name': 'Luc...         0.0     87.0
# 64991  [{'id': 26065, 'logo_path': None, 'name': 'Pis...   4588389.0    111.0
#
#          status                    title  ...  Genre_History  Genre_Family  \
# 0      Released          The Fantasticks  ...          False         False
# 1      Released            For the Cause  ...          False         False
# 2      Released                     Gang  ...          False         False
# 3      Released     In the Mood for Love  ...          False         False
# 4      Released           Chinese Coffee  ...          False         False
# ...         ...                      ...  ...            ...           ...
# 64987  Released            Heiko's World  ...          False         False
# 64988  Released  India Sweets and Spices  ...          False         False
# 64989  Released              The Hunting  ...          False         False
# 64990  Released             The Scrapper  ...          False         False
# 64991  Released               The Cursed  ...          False         False
#
#       Genre_Mystery  Genre_Western  Genre_War  Genre_TV Movie  \
# 0             False          False      False           False
# 1             False          False      False           False
# 2             False          False      False           False
# 3             False          False      False           False
# 4             False          False      False           False
# ...             ...            ...        ...             ...
# 64987         False          False      False           False
# 64988         False          False      False           False
# 64989         False          False      False           False
# 64990         False          False      False           False
# 64991          True          False      False           False
#
#        Genre_Documentary    year  month   day
# 0                  False  2000.0    9.0  22.0
# 1                  False  2000.0   11.0  15.0
# 2                  False  2000.0    4.0  14.0
# 3                  False  2000.0    9.0  29.0
# 4                  False  2000.0    9.0   2.0
# ...                  ...     ...    ...   ...
# 64987              False  2021.0    9.0   8.0
# 64988              False  2021.0   11.0  19.0
# 64989              False  2022.0    1.0  21.0
# 64990              False  2021.0   12.0   7.0
# 64991              False  2021.0    7.0  28.0
#
# [64968 rows x 35 columns]

# %% [markdown]
# ## New Filtering
#
# Make sure to only keep:
#
# * Status=Released.
# * Budget >0
# * Revenue >0

# %%
## Check status
df['status'].value_counts()
# Out:
# Released           64929
# Post Production       32
# In Production          7
# Name: status, dtype: int64

# %%
## Save only Released status
df = df.loc[ df['status'] == 'Released']
df = df.drop(columns=['status'])
df
# Out:
#          imdb_id  adult  belongs_to_collection      budget  popularity  \
# 0      tt0113026    0.0                  False  10000000.0       2.615
# 1      tt0113092    0.0                  False         0.0       1.993
# 2      tt0116391    0.0                  False         0.0       0.676
# 3      tt0118694    0.0                  False    150000.0      20.312
# 4      tt0118852    0.0                  False         0.0       5.350
# ...          ...    ...                    ...         ...         ...
# 64987  tt9895024    0.0                  False         0.0       0.688
# 64988  tt9896876    0.0                  False         0.0       4.490
# 64989  tt9898844    0.0                  False         0.0     472.600
# 64990  tt9900940    0.0                  False         0.0       2.727
# 64991  tt9907782    0.0                  False         0.0      35.350
#
#                                     production_companies     revenue  runtime  \
# 0      [{'id': 51207, 'logo_path': None, 'name': 'Sul...         0.0     86.0
# 1      [{'id': 7405, 'logo_path': '/rfnws0uY8rsNAsrLb...         0.0    100.0
# 2                                                     []         0.0    152.0
# 3      [{'id': 539, 'logo_path': None, 'name': 'Block...  12854953.0     99.0
# 4      [{'id': 67930, 'logo_path': None, 'name': 'Cha...         0.0     99.0
# ...                                                  ...         ...      ...
# 64987  [{'id': 154995, 'logo_path': None, 'name': 'AS...         0.0    118.0
# 64988  [{'id': 737, 'logo_path': '/dK1GZ1u4our8sJW0St...         0.0    101.0
# 64989  [{'id': 160303, 'logo_path': None, 'name': 'Mo...         0.0     91.0
# 64990  [{'id': 91999, 'logo_path': None, 'name': 'Luc...         0.0     87.0
# 64991  [{'id': 26065, 'logo_path': None, 'name': 'Pis...   4588389.0    111.0
#
#                          title  vote_average  ...  Genre_History Genre_Family  \
# 0              The Fantasticks           5.4  ...          False        False
# 1                For the Cause           4.4  ...          False        False
# 2                         Gang           0.0  ...          False        False
# 3         In the Mood for Love           8.1  ...          False        False
# 4               Chinese Coffee           6.9  ...          False        False
# ...                        ...           ...  ...            ...          ...
# 64987            Heiko's World           0.0  ...          False        False
# 64988  India Sweets and Spices           6.0  ...          False        False
# 64989              The Hunting           4.9  ...          False        False
# 64990             The Scrapper           6.0  ...          False        False
# 64991               The Cursed           7.0  ...          False        False
#
#        Genre_Mystery  Genre_Western  Genre_War  Genre_TV Movie  \
# 0              False          False      False           False
# 1              False          False      False           False
# 2              False          False      False           False
# 3              False          False      False           False
# 4              False          False      False           False
# ...              ...            ...        ...             ...
# 64987          False          False      False           False
# 64988          False          False      False           False
# 64989          False          False      False           False
# 64990          False          False      False           False
# 64991           True          False      False           False
#
#        Genre_Documentary    year  month   day
# 0                  False  2000.0    9.0  22.0
# 1                  False  2000.0   11.0  15.0
# 2                  False  2000.0    4.0  14.0
# 3                  False  2000.0    9.0  29.0
# 4                  False  2000.0    9.0   2.0
# ...                  ...     ...    ...   ...
# 64987              False  2021.0    9.0   8.0
# 64988              False  2021.0   11.0  19.0
# 64989              False  2022.0    1.0  21.0
# 64990              False  2021.0   12.0   7.0
# 64991              False  2021.0    7.0  28.0
#
# [64929 rows x 34 columns]

# %%
## filter out financials that don't have financial data
df = df.loc[(df['budget'] >0 ) & (df['revenue']>0)]
df
# Out:
#          imdb_id  adult  belongs_to_collection       budget  popularity  \
# 3      tt0118694    0.0                  False     150000.0      20.312
# 10     tt0120467    0.0                  False     120000.0       7.950
# 12     tt0120630    0.0                   True   45000000.0      45.071
# 15     tt0120753    0.0                  False    8000000.0       9.533
# 16     tt0120755    0.0                   True  125000000.0      34.605
# ...          ...    ...                    ...          ...         ...
# 64917  tt9639470    0.0                  False   43000000.0     171.211
# 64922  tt9664108    0.0                  False   20000000.0     114.220
# 64957  tt9784798    0.0                  False   26000000.0      19.389
# 64969  tt9844322    0.0                  False   17516235.0      14.901
# 64970  tt9844522    0.0                   True   15000000.0     134.478
#
#                                     production_companies      revenue  \
# 3      [{'id': 539, 'logo_path': None, 'name': 'Block...   12854953.0
# 10     [{'id': 102045, 'logo_path': None, 'name': 'Ch...      14904.0
# 12     [{'id': 521, 'logo_path': '/kP7t6RwGz2AvvTkvnI...  224834564.0
# 15     [{'id': 1490, 'logo_path': None, 'name': 'Kint...     105983.0
# 16     [{'id': 4, 'logo_path': '/fycMZt242LVjagMByZOL...  546388105.0
# ...                                                  ...          ...
# 64917  [{'id': 10146, 'logo_path': '/xnFIOeq5cKw09kCW...   22957625.0
# 64922  [{'id': 148185, 'logo_path': None, 'name': 'No...    4284903.0
# 64957  [{'id': 79426, 'logo_path': '/8aEC7xem9YwHNCDo...    6416063.0
# 64969  [{'id': 2902, 'logo_path': '/nSPZ1BNASeC2dxJKB...   19002036.0
# 64970  [{'id': 333, 'logo_path': '/5xUJfzPZ8jWJUDzYtI...   44888959.0
#
#        runtime                                 title  vote_average  ...  \
# 3         99.0                  In the Mood for Love           8.1  ...
# 10        87.0                                Vulgar           5.5  ...
# 12        84.0                           Chicken Run           6.7  ...
# 15       122.0              The Million Dollar Hotel           5.9  ...
# 16       123.0                Mission: Impossible II           6.1  ...
# ...        ...                                   ...           ...  ...
# 64917    117.0                    Last Night in Soho           7.5  ...
# 64922    108.0                              Voyagers           6.1  ...
# 64957    126.0           Judas and the Black Messiah           7.4  ...
# 64969    120.0          Kaamelott: The First Chapter           6.9  ...
# 64970     88.0  Escape Room: Tournament of Champions           6.7  ...
#
#        Genre_History Genre_Family  Genre_Mystery  Genre_Western  Genre_War  \
# 3              False        False          False          False      False
# 10             False        False          False          False      False
# 12             False         True          False          False      False
# 15             False        False          False          False      False
# 16             False        False          False          False      False
# ...              ...          ...            ...            ...        ...
# 64917          False        False           True          False      False
# 64922          False        False          False          False      False
# 64957           True        False          False          False      False
# 64969          False        False          False          False      False
# 64970          False        False           True          False      False
#
#        Genre_TV Movie  Genre_Documentary    year  month   day
# 3               False              False  2000.0    9.0  29.0
# 10              False              False  2002.0    4.0  26.0
# 12              False              False  2000.0    6.0  21.0
# 15              False              False  2000.0    2.0   9.0
# 16              False              False  2000.0    5.0  24.0
# ...               ...                ...     ...    ...   ...
# 64917           False              False  2021.0   10.0  21.0
# 64922           False              False  2021.0    4.0   8.0
# 64957           False              False  2021.0    2.0  12.0
# 64969           False              False  2021.0    7.0  21.0
# 64970           False              False  2021.0    7.0   1.0
#
# [5820 rows x 34 columns]

# %% [markdown]
# #### Production Company

# %%
df['production_companies']
# Out:
# 3        [{'id': 539, 'logo_path': None, 'name': 'Block...
# 10       [{'id': 102045, 'logo_path': None, 'name': 'Ch...
# 12       [{'id': 521, 'logo_path': '/kP7t6RwGz2AvvTkvnI...
# 15       [{'id': 1490, 'logo_path': None, 'name': 'Kint...
# 16       [{'id': 4, 'logo_path': '/fycMZt242LVjagMByZOL...
#                                ...
# 64917    [{'id': 10146, 'logo_path': '/xnFIOeq5cKw09kCW...
# 64922    [{'id': 148185, 'logo_path': None, 'name': 'No...
# 64957    [{'id': 79426, 'logo_path': '/8aEC7xem9YwHNCDo...
# 64969    [{'id': 2902, 'logo_path': '/nSPZ1BNASeC2dxJKB...
# 64970    [{'id': 333, 'logo_path': '/5xUJfzPZ8jWJUDzYtI...
# Name: production_companies, Length: 5820, dtype: object

# %%
#getting longest string to check for multiple companies
idxmax = df['production_companies'].apply(len).idxmax()
idxmax
# Out:
# 143

# %%
test = df.loc[idxmax, 'production_companies']
test
# Out:
# "[{'id': 53671, 'logo_path': None, 'name': 'Lantia Cinema & Audiovisivi', 'origin_country': ''}, {'id': 8, 'logo_path': '/78ilmDNTpdCfsakrsLqmAUkFTrO.png', 'name': 'Fine Line Features', 'origin_country': ''}, {'id': 76, 'logo_path': '/nebkQYtQKhZyHJfh5v0oGpNbPzu.png', 'name': 'Zentropa Entertainments', 'origin_country': 'DK'}, {'id': 119, 'logo_path': '/1di2gITGUZr730AMuMKiCrP90Vl.png', 'name': 'DR', 'origin_country': 'DK'}, {'id': 157, 'logo_path': None, 'name': 'SVT Drama', 'origin_country': ''}, {'id': 201, 'logo_path': '/6UIpEURdjnmcJPwgTDRzVRuwADr.png', 'name': 'ARTE', 'origin_country': 'FR'}, {'id': 321, 'logo_path': '/pfp6VWF3tYfOHHVRHpYe2iGcYrf.png', 'name': 'Memfis Film', 'origin_country': 'SE'}, {'id': 591, 'logo_path': '/q5I5RDwMEiqoNmfaJgd2LraEOJY.png', 'name': 'France 3 Cinéma', 'origin_country': 'FR'}, {'id': 2996, 'logo_path': None, 'name': 'Angel films', 'origin_country': ''}, {'id': 5975, 'logo_path': '/vvjgoKygWWYZvYyidT3RmOCq5If.png', 'name': 'YLE', 'origin_country': 'FI'}, {'id': 7330, 'logo_path': None, 'name': 'Blind Spot Pictures', 'origin_country': 'FI'}, {'id': 8659, 'logo_path': '/96hCWEsfmTZQsoUap0CcG21qaA.png', 'name': 'VPRO', 'origin_country': 'NL'}, {'id': 11239, 'logo_path': None, 'name': 'Liberator Productions', 'origin_country': 'FR'}, {'id': 14937, 'logo_path': None, 'name': 'Íslenska kvikmyndasamsteypan', 'origin_country': 'IS'}, {'id': 30268, 'logo_path': None, 'name': 'Pain Unlimited GmbH Filmproduktion', 'origin_country': ''}, {'id': 53667, 'logo_path': None, 'name': 'Trust Film Svenska', 'origin_country': ''}, {'id': 53668, 'logo_path': None, 'name': 'Cinematograph A/S', 'origin_country': ''}, {'id': 53669, 'logo_path': None, 'name': 'What Else? B.V', 'origin_country': ''}, {'id': 53670, 'logo_path': None, 'name': 'Filmek A/S', 'origin_country': ''}, {'id': 6705, 'logo_path': '/e8EXNSfwr5E9d3TR8dHKbQnQK4W.png', 'name': 'Film4 Productions', 'origin_country': 'GB'}, {'id': 104, 'logo_path': '/9aotxauvc9685tq9pTcRJszuT06.png', 'name': 'Canal+', 'origin_country': 'FR'}, {'id': 94, 'logo_path': '/huC7HqorvUThGIrENrbcHmQVUA0.png', 'name': 'ARTE France Cinéma', 'origin_country': 'FR'}, {'id': 2801, 'logo_path': '/bswb1PLLsKDUXMLgy42bZtCtIde.png', 'name': 'Film i Väst', 'origin_country': 'SE'}, {'id': 447, 'logo_path': None, 'name': 'TV 1000 Sverige', 'origin_country': 'SE'}, {'id': 46, 'logo_path': '/3xFdKHLXPGHEbrAkmsepGE8974Y.png', 'name': 'WDR', 'origin_country': 'DE'}, {'id': 47, 'logo_path': '/i7Z9ot2o3N5Sa3HrF09kniFs2y8.png', 'name': 'Constantin Film', 'origin_country': 'DE'}]"

# %%
# using regular expressions to extrap just the name
import re
exp= r"\'name\'\:.?\'(\w*.*?)\'"
re.findall(exp, test)
# Out:
# ['Lantia Cinema & Audiovisivi',
#  'Fine Line Features',
#  'Zentropa Entertainments',
#  'DR',
#  'SVT Drama',
#  'ARTE',
#  'Memfis Film',
#  'France 3 Cinéma',
#  'Angel films',
#  'YLE',
#  'Blind Spot Pictures',
#  'VPRO',
#  'Liberator Productions',
#  'Íslenska kvikmyndasamsteypan',
#  'Pain Unlimited GmbH Filmproduktion',
#  'Trust Film Svenska',
#  'Cinematograph A/S',
#  'What Else? B.V',
#  'Filmek A/S',
#  'Film4 Productions',
#  'Canal+',
#  'ARTE France Cinéma',
#  'Film i Väst',
#  'TV 1000 Sverige',
#  'WDR',
#  'Constantin Film']

# %%
def get_prod_company_names(x):
    if x=='[]':
        return ["MISSING"]
    
    exp= r"\'name\'\:.?\'(\w*.*?)\'"
    companies = re.findall(exp, x)
    return companies

# %%
# test function
get_prod_company_names(test)
# Out:
# ['Lantia Cinema & Audiovisivi',
#  'Fine Line Features',
#  'Zentropa Entertainments',
#  'DR',
#  'SVT Drama',
#  'ARTE',
#  'Memfis Film',
#  'France 3 Cinéma',
#  'Angel films',
#  'YLE',
#  'Blind Spot Pictures',
#  'VPRO',
#  'Liberator Productions',
#  'Íslenska kvikmyndasamsteypan',
#  'Pain Unlimited GmbH Filmproduktion',
#  'Trust Film Svenska',
#  'Cinematograph A/S',
#  'What Else? B.V',
#  'Filmek A/S',
#  'Film4 Productions',
#  'Canal+',
#  'ARTE France Cinéma',
#  'Film i Väst',
#  'TV 1000 Sverige',
#  'WDR',
#  'Constantin Film']

# %%
## Save new clean prod_comapny col and explode
df['prod_company'] = df['production_companies'].apply(get_prod_company_names)
prod_companies = df['prod_company'].explode()
prod_companies.value_counts().head(49)
# Out:
# /Users/oleksandraaliyeva/opt/anaconda3/envs/dojo-env/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Warner Bros. Pictures        339
# Universal Pictures           330
# Columbia Pictures            284
# 20th Century Fox             236
# Paramount                    220
# New Line Cinema              181
# MISSING                      180
# Canal+                       168
# Walt Disney Pictures         162
# Lionsgate                    124
# DreamWorks Pictures          124
# Relativity Media             123
# Village Roadshow Pictures    122
# Metro-Goldwyn-Mayer          121
# Miramax                      118
# Touchstone Pictures          112
# StudioCanal                  107
# Screen Gems                   81
# Fox Searchlight Pictures      77
# Dimension Films               76
# Summit Entertainment          73
# Regency Enterprises           73
# Dune Entertainment            72
# Focus Features                70
# TSG Entertainment             67
# Sony Pictures                 67
# Epsilon Motion Pictures       65
# Working Title Films           60
# New Regency Pictures          57
# Fox 2000 Pictures             55
# Blumhouse Productions         55
# Original Film                 53
# TF1 Films Production          52
# Revolution Studios            52
# Millennium Films              52
# Film4 Productions             51
# BBC Films                     51
# NPV Entertainment             51
# Legendary Pictures            51
# Spyglass Entertainment        50
# The Weinstein Company         50
# Ingenious Media               49
# Ciné+                         48
# CJ Entertainment              47
# Scott Rudin Productions       47
# Scott Free Productions        45
# France 2 Cinéma               45
# EuropaCorp                    45
# Amblin Entertainment          44
# Name: prod_company, dtype: int64

# %%
prod_companies.nunique()
# Out:
# 6349

# %% [markdown]
# * Common Prod Company Encoding:
#   - Keep top 50 most common companies an one hot encode

# %%
## saving the 50 most common companies
common_companies = sorted(prod_companies.value_counts().head(50).index)
common_companies
# Out:
# ['20th Century Fox',
#  'Amblin Entertainment',
#  'BBC Films',
#  'Blumhouse Productions',
#  'CJ Entertainment',
#  'Canal+',
#  'Ciné+',
#  'Columbia Pictures',
#  'Dimension Films',
#  'DreamWorks Animation',
#  'DreamWorks Pictures',
#  'Dune Entertainment',
#  'Epsilon Motion Pictures',
#  'EuropaCorp',
#  'Film4 Productions',
#  'Focus Features',
#  'Fox 2000 Pictures',
#  'Fox Searchlight Pictures',
#  'France 2 Cinéma',
#  'Ingenious Media',
#  'Legendary Pictures',
#  'Lionsgate',
#  'MISSING',
#  'Metro-Goldwyn-Mayer',
#  'Millennium Films',
#  'Miramax',
#  'NPV Entertainment',
#  'New Line Cinema',
#  'New Regency Pictures',
#  'Original Film',
#  'Paramount',
#  'Regency Enterprises',
#  'Relativity Media',
#  'Revolution Studios',
#  'Scott Free Productions',
#  'Scott Rudin Productions',
#  'Screen Gems',
#  'Sony Pictures',
#  'Spyglass Entertainment',
#  'StudioCanal',
#  'Summit Entertainment',
#  'TF1 Films Production',
#  'TSG Entertainment',
#  'The Weinstein Company',
#  'Touchstone Pictures',
#  'Universal Pictures',
#  'Village Roadshow Pictures',
#  'Walt Disney Pictures',
#  'Warner Bros. Pictures',
#  'Working Title Films']

# %%
#manually ohe top 20 companies
for company in common_companies:
    df[f"ProdComp_{company}"] = df['production_companies'].str.contains(company, regex=False)
# Out:
# /Users/oleksandraaliyeva/opt/anaconda3/envs/dojo-env/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#dropping columns
drop_for_model = ['title','imdb_id','prod_company','production_companies']
df = df.drop(columns=drop_for_model)
df
# Out:
#        adult  belongs_to_collection       budget  popularity      revenue  \
# 3        0.0                  False     150000.0      20.312   12854953.0
# 10       0.0                  False     120000.0       7.950      14904.0
# 12       0.0                   True   45000000.0      45.071  224834564.0
# 15       0.0                  False    8000000.0       9.533     105983.0
# 16       0.0                   True  125000000.0      34.605  546388105.0
# ...      ...                    ...          ...         ...          ...
# 64917    0.0                  False   43000000.0     171.211   22957625.0
# 64922    0.0                  False   20000000.0     114.220    4284903.0
# 64957    0.0                  False   26000000.0      19.389    6416063.0
# 64969    0.0                  False   17516235.0      14.901   19002036.0
# 64970    0.0                   True   15000000.0     134.478   44888959.0
#
#        runtime  vote_average  vote_count certification  Genre_Comedy  ...  \
# 3         99.0           8.1      1859.0            PG         False  ...
# 10        87.0           5.5        40.0             R         False  ...
# 12        84.0           6.7      3991.0             G          True  ...
# 15       122.0           5.9       246.0             R         False  ...
# 16       123.0           6.1      5265.0         PG-13         False  ...
# ...        ...           ...         ...           ...           ...  ...
# 64917    117.0           7.5      1573.0             R         False  ...
# 64922    108.0           6.1       508.0         PG-13         False  ...
# 64957    126.0           7.4      1011.0           NaN         False  ...
# 64969    120.0           6.9       455.0           NaN          True  ...
# 64970     88.0           6.7      1129.0         PG-13         False  ...
#
#        ProdComp_Summit Entertainment  ProdComp_TF1 Films Production  \
# 3                              False                          False
# 10                             False                          False
# 12                             False                          False
# 15                             False                          False
# 16                             False                          False
# ...                              ...                            ...
# 64917                          False                          False
# 64922                          False                          False
# 64957                          False                          False
# 64969                          False                          False
# 64970                          False                          False
#
#        ProdComp_TSG Entertainment  ProdComp_The Weinstein Company  \
# 3                           False                           False
# 10                          False                           False
# 12                          False                           False
# 15                          False                           False
# 16                          False                           False
# ...                           ...                             ...
# 64917                       False                           False
# 64922                       False                           False
# 64957                       False                           False
# 64969                       False                           False
# 64970                       False                           False
#
#        ProdComp_Touchstone Pictures  ProdComp_Universal Pictures  \
# 3                             False                        False
# 10                            False                        False
# 12                            False                        False
# 15                            False                        False
# 16                            False                        False
# ...                             ...                          ...
# 64917                         False                        False
# 64922                         False                        False
# 64957                         False                        False
# 64969                         False                        False
# 64970                         False                        False
#
#        ProdComp_Village Roadshow Pictures  ProdComp_Walt Disney Pictures  \
# 3                                   False                          False
# 10                                  False                          False
# 12                                  False                          False
# 15                                  False                          False
# 16                                  False                          False
# ...                                   ...                            ...
# 64917                               False                          False
# 64922                               False                          False
# 64957                               False                          False
# 64969                               False                          False
# 64970                               False                          False
#
#        ProdComp_Warner Bros. Pictures  ProdComp_Working Title Films
# 3                               False                         False
# 10                              False                         False
# 12                              False                         False
# 15                              False                         False
# 16                              False                         False
# ...                               ...                           ...
# 64917                           False                          True
# 64922                           False                         False
# 64957                            True                         False
# 64969                           False                         False
# 64970                           False                         False
#
# [5820 rows x 81 columns]

# %% [markdown]
# ## Checking for Linearity

# %%
## concatenating training data into plot_df
plot_df = pd.concat([X_train_df,y_train],axis=1)
plot_df
# Out:
#        certification_G  certification_MISSING  certification_NC-17  \
# 5230               0.0            102000000.0               19.860
# 23535              0.0             40000000.0               30.853
# 217                0.0              6000000.0                8.394
# 42087              0.0              6000000.0               23.877
# 61412              0.0              5000000.0               28.513
# ...                ...                    ...                  ...
# 10250              0.0             20000000.0               24.683
# 214                0.0             90000000.0               12.649
# 55848              0.0               208000.0                0.831
# 27389              0.0              3000000.0               49.387
# 57168              0.0              1600000.0               23.019
#
#        certification_NR  certification_PG  certification_PG-13  \
# 5230               99.0               6.2               2181.0
# 23535              93.0               6.4               2588.0
# 217               122.0               6.7                239.0
# 42087             106.0               5.9               1011.0
# 61412             108.0               7.3               2214.0
# ...                 ...               ...                  ...
# 10250              92.0               6.3               2806.0
# 214               114.0               6.0               1105.0
# 55848               0.0               7.4                  5.0
# 27389             110.0               6.8               4359.0
# 57168              91.0               7.2                139.0
#
#        certification_R  adult  budget  popularity  ...  \
# 5230            2001.0    6.0     7.0         0.0  ...
# 23535           2011.0    1.0    13.0         0.0  ...
# 217             2000.0    9.0     6.0         0.0  ...
# 42087           2016.0   10.0    19.0         0.0  ...
# 61412           2020.0   12.0     4.0         0.0  ...
# ...                ...    ...     ...         ...  ...
# 10250           2004.0    6.0    18.0         0.0  ...
# 214             2000.0    3.0    10.0         0.0  ...
# 55848           2019.0   10.0    10.0         0.0  ...
# 27389           2012.0    3.0    29.0         0.0  ...
# 57168           2019.0   11.0    22.0         0.0  ...
#
#        ProdComp_TSG Entertainment  ProdComp_The Weinstein Company  \
# 5230                          0.0                             0.0
# 23535                         0.0                             0.0
# 217                           0.0                             0.0
# 42087                         0.0                             0.0
# 61412                         0.0                             0.0
# ...                           ...                             ...
# 10250                         0.0                             0.0
# 214                           0.0                             0.0
# 55848                         0.0                             0.0
# 27389                         0.0                             0.0
# 57168                         0.0                             0.0
#
#        ProdComp_Touchstone Pictures  ProdComp_Universal Pictures  \
# 5230                            0.0                          0.0
# 23535                           0.0                          0.0
# 217                             0.0                          0.0
# 42087                           0.0                          0.0
# 61412                           0.0                          0.0
# ...                             ...                          ...
# 10250                           0.0                          0.0
# 214                             1.0                          0.0
# 55848                           0.0                          0.0
# 27389                           0.0                          0.0
# 57168                           0.0                          0.0
#
#        ProdComp_Village Roadshow Pictures  ProdComp_Walt Disney Pictures  \
# 5230                                  1.0                            0.0
# 23535                                 0.0                            0.0
# 217                                   0.0                            0.0
# 42087                                 0.0                            0.0
# 61412                                 0.0                            0.0
# ...                                   ...                            ...
# 10250                                 0.0                            0.0
# 214                                   0.0                            0.0
# 55848                                 0.0                            0.0
# 27389                                 0.0                            0.0
# 57168                                 0.0                            0.0
#
#        ProdComp_Warner Bros. Pictures  ProdComp_Working Title Films  const  \
# 5230                              1.0                           0.0    1.0
# 23535                             0.0                           0.0    1.0
# 217                               0.0                           0.0    1.0
# 42087                             0.0                           0.0    1.0
# 61412                             0.0                           0.0    1.0
# ...                               ...                           ...    ...
# 10250                             0.0                           0.0    1.0
# 214                               0.0                           0.0    1.0
# 55848                             0.0                           0.0    1.0
# 27389                             0.0                           0.0    1.0
# 57168                             0.0                           0.0    1.0
#
#            revenue
# 5230   147080413.0
# 23535   51070807.0
# 217     10994533.0
# 42087    1305195.0
# 61412   14784114.0
# ...            ...
# 10250  167722310.0
# 214     60874615.0
# 55848      78254.0
# 27389   82515113.0
# 57168    5750000.0
#
# [4365 rows x 88 columns]

# %%
## save plot_cols list to show (dropping genre from plot_df from pair_plot)
genre_cols = [c for c in plot_df if c.startswith('Genre')]
comp_cols = [c for c in plot_df if c.startswith('ProdComp')]

plot_cols = plot_df.drop(columns=[*genre_cols, *comp_cols]).columns
plot_cols
# Out:
# Index(['certification_G', 'certification_MISSING', 'certification_NC-17',
#        'certification_NR', 'certification_PG', 'certification_PG-13',
#        'certification_R', 'adult', 'budget', 'popularity', 'runtime',
#        'vote_average', 'vote_count', 'year', 'month', 'day',
#        'belongs_to_collection', 'const', 'revenue'],
#       dtype='object')

# %%
len(plot_cols)
# Out:
# 19

# %%
#plot first 6 features
sns.pairplot(data=plot_df, y_vars='revenue', x_vars=plot_cols[:6]);

# %%
#plot next 6 features
sns.pairplot(data=plot_df, y_vars='revenue', x_vars=plot_cols[6:13]);

# %%
#plot remaining features
sns.pairplot(data=plot_df, y_vars='revenue', x_vars=plot_cols[13:]);

# %% [markdown]
# # Functionize all of the preprocessing

# %%
def get_train_test_split(df_, y_col='revenue',drop_cols=[]):
    
    ## Make copy of input df
    df = df_.copy()
    
    ## filter columns in drop cols (if exist)
    final_drop_cols = []
    [df.drop(columns=c,inplace=True) for c in df.columns if c in drop_cols]
    
    
    ## Make x and y variables
    y = df[y_col].copy()
    X = df.drop(columns=[y_col]).copy()

    X_train, X_test, y_train, y_test = train_test_split(X,y)#, random_state=321)
    

    
    ## make cat selector and using it to save list of column names
    cat_select = make_column_selector(dtype_include='object')
    cat_cols = cat_select(X_train)


    ## make num selector and using it to save list of column names
    num_select = make_column_selector(dtype_include='number')
    num_cols = num_select(X_train)


    ## select manually OHE cols for later
    bool_select = make_column_selector(dtype_include='bool')
    already_ohe_cols = bool_select(X_train)

    ## convert manual ohe to int
    X_train[already_ohe_cols] = X_train[already_ohe_cols].astype(int)
    X_test[already_ohe_cols] = X_test[already_ohe_cols].astype(int)

    ## make pipelines
    cat_pipe = make_pipeline(SimpleImputer(strategy='constant',
                                           fill_value='MISSING'),
                             OneHotEncoder(handle_unknown='ignore', sparse=False))
    num_pipe = make_pipeline(SimpleImputer(strategy='mean'),#StandardScaler()
                            )

    preprocessor = make_column_transformer((num_pipe, num_cols),
                                           (cat_pipe,cat_cols),remainder='passthrough')
    
    

    ## fit the col transformer
    preprocessor.fit(X_train)

    ## Finding the categorical pipeline in our col transformer.
    preprocessor.named_transformers_['pipeline-2']

    ## B) Using list-slicing to find the encoder 
    cat_features = preprocessor.named_transformers_['pipeline-2'][-1].get_feature_names_out(cat_cols)


    ## Create the empty list
    final_features = [*cat_features,*num_cols,*already_ohe_cols]

    ## Make df verisons of x data
    X_train_tf = pd.DataFrame( preprocessor.transform(X_train), 
                              columns=final_features, index=X_train.index)


    X_test_tf = pd.DataFrame( preprocessor.transform(X_test),
                             columns=final_features, index=X_test.index)


    ### Adding a Constant for Statsmodels
    ## Make final X_train_df and X_test_df with constants added
    X_train_df = sm.add_constant(X_train_tf, prepend=False, has_constant='add')
    X_test_df = sm.add_constant(X_test_tf, prepend=False, has_constant='add')
    return X_train_df, y_train, X_test_df, y_test

# %%
def evaluate_ols(result,X_train_df, y_train, show_summary=True):
    """Plots a Q-Q Plot and residual plot for a statsmodels OLS regression.
    """
    if show_summary==True:
        try:
            display(result.summary())
        except:
            pass
    
    ## save residuals from result
    y_pred = result.predict(X_train_df)
    resid = y_train - y_pred
    
    fig, axes = plt.subplots(ncols=2,figsize=(12,5))
    
    ## Normality 
    sm.graphics.qqplot(resid,line='45',fit=True,ax=axes[0]);
    
    ## Homoscedasticity
    ax = axes[1]
    ax.scatter(y_pred, resid, edgecolor='white',lw=1)
    ax.axhline(0,zorder=0)
    ax.set(ylabel='Residuals',xlabel='Predicted Value');
    plt.tight_layout()

# %% [markdown]
# # Checking Model Assumptions
#
# ## Modeling
#
# ## Baseline Model

# %%
## instantiate an OLS model WITH the training data.
model = sm.OLS(y_train, X_train_df)

## Fit the model and view the summary
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                revenue   R-squared:                       0.768
# Model:                            OLS   Adj. R-squared:                  0.763
# Method:                 Least Squares   F-statistic:                
Durbin-Watson:                   1.984
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           522306.406
# Skew:                           3.869   Prob(JB):                         0.00
# Kurtosis:                      56.027   Cond. No.                     4.64e+23
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.76e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
## Get train data performance from skearn to confirm matches OLS
y_hat_train = result.predict(X_train_df)
print(f'Training R^2: {r2_score(y_train, y_hat_train):.3f}')

## Get test data performance
y_hat_test = result.predict(X_test_df)
print(f'Testing R^2: {r2_score(y_test, y_hat_test):.3f}')
# Out:
# Training R^2: 0.768
# Testing R^2: 0.753

# %% [markdown]
# ## The Assumptions of Linear Regression
# * The 4 Assumptions of a Linear Regression are:
#  - Linearity: That the input features have a linear relationship with the target.
#  - Independence of features (AKA Little-to-No Multicollinearity): That the features are not strongly related to other features.
#  - Normality: The model's residuals are approximately normally distributed.
#  - Homoscedasticity: The model residuals have equal variance across all predictions.

# %%
evaluate_ols(result,X_train_df, y_train)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                revenue   R-squared:                       0.768
# Model:                            OLS   Adj. R-squared:                  0.763
# Method:                 Least Squares   F-statistic:                     170.4
# Date:                Fri, 20 May 2022   Prob (F-statistic):               0.00
# Time:                        10:57:04   Log-Likelihood:                -85982.
# No. Observations:                4365   AIC:                         1.721e+05
# Df Residuals:                    4281   BIC:                         1.727e+05
# Df Model:                          83
# Covariance Type:            nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# certification_G                     9.807e+06   8.78e+07      0.112      0.911   -1.62e+08    1.82e+08
# certification_MISSING                  1.7817      0.054     32.787      0.000       1.675       1.888
# certification_NC-17                 3.345e+04   2.36e+04      1.419      0.156   -1.28e+04    7.97e+04
# certification_NR                    2.288e+05   7.56e+04      3.028      0.002    8.07e+04    3.77e+05
# certification_PG                   -3.634e+06   1.33e+06     -2.732      0.006   -6.24e+06   -1.03e+06
# certification_PG-13                 2.961e+04    605.150     48.937      0.000    2.84e+04    3.08e+04
# certification_R                     5.527e+05   2.46e+05      2.250      0.024    7.12e+04    1.03e+06
# adult                              -1.571e+05   3.94e+05     -0.398      0.690    -9.3e+05    6.16e+05
# budget                             -7.945e+04   1.56e+05     -0.508      0.611   -3.86e+05    2.27e+05
# popularity                         -1.403e+08   6.19e+07     -2.268      0.023   -2.62e+08    -1.9e+07
# runtime                            -1.377e+08   6.23e+07     -2.210      0.027    -2.6e+08   -1.55e+07
# vote_average                        -1.34e+08   6.78e+07     -1.976      0.048   -2.67e+08   -1.08e+06
# vote_count                         -1.432e+08   6.25e+07     -2.290      0.022   -2.66e+08   -2.06e+07
# year                               -1.303e+08   6.19e+07     -2.105      0.035   -2.52e+08   -8.96e+06
# month                              -1.433e+08   6.18e+07     -2.318      0.021   -2.65e+08   -2.21e+07
# day                                -1.594e+08   6.18e+07     -2.581      0.010   -2.81e+08   -3.83e+07
# belongs_to_collection               4.803e+07   3.66e+06     13.109      0.000    4.08e+07    5.52e+07
# Genre_Comedy                        8.361e+06   3.53e+06      2.369      0.018    1.44e+06    1.53e+07
# Genre_Music                         6.842e+06   8.37e+06      0.817      0.414   -9.57e+06    2.33e+07
# Genre_Romance                       7.163e+06   3.84e+06      1.866      0.062   -3.64e+05    1.47e+07
# Genre_Science Fiction              -2.802e+07   5.02e+06     -5.586      0.000   -3.79e+07   -1.82e+07
# Genre_Drama                         9.354e+05   3.46e+06      0.270      0.787   -5.86e+06    7.73e+06
# ProdComp_The Weinstein Company     -3.203e+07   1.41e+07     -2.267      0.023   -5.97e+07   -4.33e+06
# ProdComp_Touchstone Pictures        9.456e+06   1.02e+07      0.927      0.354   -1.06e+07    2.95e+07
# ProdComp_Universal Pictures        -4.684e+06   6.28e+06     -0.745      0.456    -1.7e+07    7.63e+06
# ProdComp_Village Roadshow Pictures -1.549e+07    1.3e+07     -1.196      0.232   -4.09e+07    9.91e+06
# ProdComp_Walt Disney Pictures      -8.195e+06   9.84e+06     -0.832      0.405   -2.75e+07    1.11e+07
# ProdComp_Warner Bros. Pictures     -2.891e+07   6.65e+06     -4.350      0.000   -4.19e+07   -1.59e+07
# ProdComp_Working Title Films       -2.406e+07   1.43e+07     -1.687      0.092    -5.2e+07    3.91e+06
# const                              -9.882e+08   4.32e+08     -2.290      0.022   -1.83e+09   -1.42e+08
# ==============================================================================
# Omnibus:                     3983.270   Durbin-Watson:                   1.984
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           522306.406
# Skew:                           3.869   Prob(JB):                         0.00
# Kurtosis:                      56.027   Cond. No.                     4.64e+23
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.76e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# ### Removing Outliers
# * Using Z-Score Rule

# %%
from scipy import stats
def find_outliers(data, verbose=True):
    outliers = np.abs(stats.zscore(data))>3
    
    if verbose:
        print(f"- {outliers.sum()} outliers found in {data.name} using Z-Scores.")
    return outliers

# %%
find_outliers(df['runtime'])
# Out:
# - 0 outliers found in runtime using Z-Scores.
# 3        False
# 10       False
# 12       False
# 15       False
# 16       False
#          ...
# 64917    False
# 64922    False
# 64957    False
# 64969    False
# 64970    False
# Name: runtime, Length: 5820, dtype: bool

# %%
## save a dictionary of the T/F outlier index for each feature in outleir_cols
outlier_cols = ['runtime','popularity','revenue']

outliers = {}

for col in outlier_cols:
    col_outliers = find_outliers(df[col])
    
    outliers[col] = col_outliers
# Out:
# - 0 outliers found in runtime using Z-Scores.
# - 47 outliers found in popularity using Z-Scores.
# - 147 outliers found in revenue using Z-Scores.

# %%
# Make new df_clean copy of df
df_clean = df.copy()

## loop through dictionary to remove outliers
for col, col_outliers in outliers.items():
    df_clean  = df_clean.loc[~col_outliers]

# %%
df_clean
# Out:
#        adult  belongs_to_collection       budget  popularity      revenue  \
# 3        0.0                  False     150000.0      20.312   12854953.0
# 10       0.0                  False     120000.0       7.950      14904.0
# 12       0.0                   True   45000000.0      45.071  224834564.0
# 15       0.0                  False    8000000.0       9.533     105983.0
# 16       0.0                   True  125000000.0      34.605  546388105.0
# ...      ...                    ...          ...         ...          ...
# 64917    0.0                  False   43000000.0     171.211   22957625.0
# 64922    0.0                  False   20000000.0     114.220    4284903.0
# 64957    0.0                  False   26000000.0      19.389    6416063.0
# 64969    0.0                  False   17516235.0      14.901   19002036.0
# 64970    0.0                   True   15000000.0     134.478   44888959.0
#
#        runtime  vote_average  vote_count certification  Genre_Comedy  ...  \
# 3         99.0           8.1      1859.0            PG         False  ...
# 10        87.0           5.5        40.0             R         False  ...
# 12        84.0           6.7      3991.0             G          True  ...
# 15       122.0           5.9       246.0             R         False  ...
# 16       123.0           6.1      5265.0         PG-13         False  ...
# ...        ...           ...         ...           ...           ...  ...
# 64917    117.0           7.5      1573.0             R         False  ...
# 64922    108.0           6.1       508.0         PG-13         False  ...
# 64957    126.0           7.4      1011.0           NaN         False  ...
# 64969    120.0           6.9       455.0           NaN          True  ...
# 64970     88.0           6.7      1129.0         PG-13         False  ...
#
#        ProdComp_Summit Entertainment  ProdComp_TF1 Films Production  \
# 3                              False                          False
# 10                             False                          False
# 12                             False                          False
# 15                             False                          False
# 16                             False                          False
# ...                              ...                            ...
# 64917                          False                          False
# 64922                          False                          False
# 64957                          False                          False
# 64969                          False                          False
# 64970                          False                          False
#
#        ProdComp_TSG Entertainment  ProdComp_The Weinstein Company  \
# 3                           False                           False
# 10                          False                           False
# 12                          False                           False
# 15                          False                           False
# 16                          False                           False
# ...                           ...                             ...
# 64917                       False                           False
# 64922                       False                           False
# 64957                       False                           False
# 64969                       False                           False
# 64970                       False                           False
#
#        ProdComp_Touchstone Pictures  ProdComp_Universal Pictures  \
# 3                             False                        False
# 10                            False                        False
# 12                            False                        False
# 15                            False                        False
# 16                            False                        False
# ...                             ...                          ...
# 64917                         False                        False
# 64922                         False                        False
# 64957                         False                        False
# 64969                         False                        False
# 64970                         False                        False
#
#        ProdComp_Village Roadshow Pictures  ProdComp_Walt Disney Pictures  \
# 3                                   False                          False
# 10                                  False                          False
# 12                                  False                          False
# 15                                  False                          False
# 16                                  False                          False
# ...                                   ...                            ...
# 64917                               False                          False
# 64922                               False                          False
# 64957                               False                          False
# 64969                               False                          False
# 64970                               False                          False
#
#        ProdComp_Warner Bros. Pictures  ProdComp_Working Title Films
# 3                               False                         False
# 10                              False                         False
# 12                              False                         False
# 15                              False                         False
# 16                              False                         False
# ...                               ...                           ...
# 64917                           False                          True
# 64922                           False                         False
# 64957                            True                         False
# 64969                           False                         False
# 64970                           False                         False
#
# [5638 rows x 81 columns]

# %% [markdown]
# ## Model 2: Outliers Removed (Z_scores)

# %%
## Use our function to make new x,y vars
X_train_df, y_train, X_test_df, y_test = get_train_test_split(df_clean)


## instantiate an OLS model WITH the training data.
model = sm.OLS(y_train, X_train_df)

## Fit the model and view the summary
result = model.fit()
evaluate_ols(result, X_train_df, y_train)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                revenue   R-squared:                       0.757
# Model:                            OLS   Adj. R-squared:                  0.752
# Method:                 Least Squares   F-statistic:                     157.5
# Date:                Fri, 20 May 2022   Prob (F-statistic):               0.00
# Time:                        11:01:59   Log-Likelihood:                -81170.
# No. Observations:                4228   AIC:                         1.625e+05
# Df Residuals:                    4145   BIC:                         1.630e+05
# Df Model:                          82
# Covariance Type:            nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# certification_G                        4.8447      4.589      1.056      0.291      -4.152      13.842
# certification_MISSING                  1.3588      0.037     36.493      0.000       1.286       1.432
# certification_NC-17                 8.006e+04   3.54e+04      2.264      0.024    1.07e+04    1.49e+05
# certification_NR                    6.307e+04   4.66e+04      1.352      0.176   -2.84e+04    1.54e+05
# certification_PG                    4.621e+04   8.41e+05      0.055      0.956    -1.6e+06     1.7e+06
# certification_PG-13                 2.043e+04    476.472     42.883      0.000    1.95e+04    2.14e+04
# certification_R                    -1.764e+05   1.55e+05     -1.141      0.254    -4.8e+05    1.27e+05
# adult                              -3.934e+05   2.42e+05     -1.625      0.104   -8.68e+05    8.13e+04
# budget                             -4.678e+04    9.6e+04     -0.487      0.626   -2.35e+05    1.41e+05
# popularity                          5.513e+07    3.9e+07      1.413      0.158   -2.14e+07    1.32e+08
# runtime                             4.291e+07   3.92e+07      1.096      0.273   -3.39e+07     1.2e+08
# vote_average                        4.335e+07   4.22e+07      1.026      0.305   -3.95e+07    1.26e+08
# vote_count                          4.309e+07   3.93e+07      1.097      0.273   -3.39e+07     1.2e+08
# ProdComp_Sony Pictures              2.233e+07   7.21e+06      3.098      0.002     8.2e+06    3.65e+07
# ProdComp_Spyglass Entertainment    -7.131e+06   9.68e+06     -0.737      0.461   -2.61e+07    1.18e+07
# ProdComp_StudioCanal               -2.855e+06   6.76e+06     -0.422      0.673   -1.61e+07    1.04e+07
# ProdComp_Summit Entertainment      -3.204e+07   7.51e+06     -4.265      0.000   -4.68e+07   -1.73e+07
# ProdComp_TF1 Films Production       1.159e+06   9.72e+06      0.119      0.905   -1.79e+07    2.02e+07
# ProdComp_TSG Entertainment          -2.04e+07   8.54e+06     -2.388      0.017   -3.71e+07   -3.65e+06
# ProdComp_The Weinstein Company     -1.403e+07    9.1e+06     -1.542      0.123   -3.19e+07     3.8e+06
# ProdComp_Touchstone Pictures        1.007e+07   6.22e+06      1.619      0.105   -2.12e+06    2.23e+07
# ProdComp_Universal Pictures         8.854e+06   4.06e+06      2.178      0.029    8.86e+05    1.68e+07
# ProdComp_Village Roadshow Pictures    1.1e+07   8.04e+06      1.369      0.171   -4.75e+06    2.68e+07
# ProdComp_Walt Disney Pictures        1.01e+06   6.46e+06      0.156      0.876   -1.17e+07    1.37e+07
# ProdComp_Warner Bros. Pictures     -9.231e+06   4.38e+06     -2.107      0.035   -1.78e+07    -6.4e+05
# ProdComp_Working Title Films       -2.824e+06   8.95e+06     -0.316      0.752   -2.04e+07    1.47e+07
# const                               3.022e+08   2.72e+08      1.112      0.266   -2.31e+08    8.35e+08
# ==============================================================================
# Omnibus:                     1707.535   Durbin-Watson:                   2.054
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            27337.825
# Skew:                           1.495   Prob(JB):                         0.00
# Kurtosis:                      15.093   Cond. No.                     4.48e+23
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.42e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# ### Removing Outliers - Using IQR Rule

# %%
## visualzie outlier-removed target
sns.boxplot(x = y_train)

# %%
def find_outliers_IQR(data, verbose=True):
    q3 = np.quantile(data,.75)
    q1 = np.quantile(data,.25)

    IQR = q3 - q1
    upper_threshold = q3 + 1.5*IQR
    lower_threshold = q1 - 1.5*IQR
    
    outliers = (data<lower_threshold) | (data>upper_threshold)
    if verbose:
        print(f"- {outliers.sum()} outliers found in {data.name} using IQR.")
        
    return outliers

# %%
outliers_z = find_outliers(df['revenue'])
outliers_iqr = find_outliers_IQR(df['revenue'])
# Out:
# - 147 outliers found in revenue using Z-Scores.
# - 611 outliers found in revenue using IQR.

# %%
## Loop to remove outliers from same clumns using new function
outlier_cols = ['runtime','popularity','revenue']

## Empty dict for both types of outliers
## save a dictionary of the T/F outlier index for each feature in outleir_cols
outlier_cols = ['runtime','popularity','revenue']

outliers_z = {}
outliers_IQR = {}

for col in outlier_cols:
    col_outliers_z = find_outliers(df[col])
    outliers_z[col] = col_outliers_z
    
    col_outliers_iqr = find_outliers_IQR(df[col])
    outliers_IQR[col] = col_outliers_iqr
    print()
## Use both functions to see the comparison for # of outliers
# Out:
# - 0 outliers found in runtime using Z-Scores.
# - 0 outliers found in runtime using IQR.
#
# - 47 outliers found in popularity using Z-Scores.
# - 631 outliers found in popularity using IQR.
#
# - 147 outliers found in revenue using Z-Scores.
# - 611 outliers found in revenue using IQR.

# %%
# Make new df_clean copy of df
df_clean_iqr = df.copy()

## loop through dictionary to remove outliers
for col, col_outliers in outliers_IQR.items():
    df_clean_iqr  = df_clean_iqr.loc[~col_outliers]
df_clean_iqr
# Out:
#        adult  belongs_to_collection      budget  popularity      revenue  \
# 3        0.0                  False    150000.0      20.312   12854953.0
# 10       0.0                  False    120000.0       7.950      14904.0
# 12       0.0                   True  45000000.0      45.071  224834564.0
# 15       0.0                  False   8000000.0       9.533     105983.0
# 18       0.0                  False  75000000.0      15.257   36754634.0
# ...      ...                    ...         ...         ...          ...
# 64826    0.0                  False  15000000.0      35.140   18192220.0
# 64862    0.0                  False  27500000.0      52.226   19046191.0
# 64869    0.0                   True  11000000.0      18.594    3189418.0
# 64957    0.0                  False  26000000.0      19.389    6416063.0
# 64969    0.0                  False  17516235.0      14.901   19002036.0
#
#        runtime  vote_average  vote_count certification  Genre_Comedy  ...  \
# 3         99.0           8.1      1859.0            PG         False  ...
# 10        87.0           5.5        40.0             R         False  ...
# 12        84.0           6.7      3991.0             G          True  ...
# 15       122.0           5.9       246.0             R         False  ...
# 18        94.0           6.6       846.0            PG         False  ...
# ...        ...           ...         ...           ...           ...  ...
# 64826    130.0           6.5      1083.0             R         False  ...
# 64862    137.0           6.4       160.0         PG-13         False  ...
# 64869    133.0           6.2       290.0           NaN         False  ...
# 64957    126.0           7.4      1011.0           NaN         False  ...
# 64969    120.0           6.9       455.0           NaN          True  ...
#
#        ProdComp_Summit Entertainment  ProdComp_TF1 Films Production  \
# 3                              False                          False
# 10                             False                          False
# 12                             False                          False
# 15                             False                          False
# 18                             False                          False
# ...                              ...                            ...
# 64826                          False                          False
# 64862                          False                          False
# 64869                          False                          False
# 64957                          False                          False
# 64969                          False                          False
#
#        ProdComp_TSG Entertainment  ProdComp_The Weinstein Company  \
# 3                           False                           False
# 10                          False                           False
# 12                          False                           False
# 15                          False                           False
# 18                          False                           False
# ...                           ...                             ...
# 64826                       False                           False
# 64862                       False                           False
# 64869                       False                           False
# 64957                       False                           False
# 64969                       False                           False
#
#        ProdComp_Touchstone Pictures  ProdComp_Universal Pictures  \
# 3                             False                        False
# 10                            False                        False
# 12                            False                        False
# 15                            False                        False
# 18                            False                        False
# ...                             ...                          ...
# 64826                         False                        False
# 64862                         False                         True
# 64869                         False                        False
# 64957                         False                        False
# 64969                         False                        False
#
#        ProdComp_Village Roadshow Pictures  ProdComp_Walt Disney Pictures  \
# 3                                   False                          False
# 10                                  False                          False
# 12                                  False                          False
# 15                                  False                          False
# 18                                  False                          False
# ...                                   ...                            ...
# 64826                               False                          False
# 64862                               False                          False
# 64869                               False                          False
# 64957                               False                          False
# 64969                               False                          False
#
#        ProdComp_Warner Bros. Pictures  ProdComp_Working Title Films
# 3                               False                         False
# 10                              False                         False
# 12                              False                         False
# 15                              False                         False
# 18                              False                         False
# ...                               ...                           ...
# 64826                           False                         False
# 64862                           False                         False
# 64869                           False                         False
# 64957                            True                         False
# 64969                           False                         False
#
# [4903 rows x 81 columns]

# %% [markdown]
# ## Model 3 - IQR Outliers Removed

# %%
## Use our function to make new x,y vars
X_train_df, y_train, X_test_df, y_test = get_train_test_split(
Durbin-Watson:                   2.043
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2240.375
# Skew:                           0.817   Prob(JB):                         0.00
# Kurtosis:                       6.458   Cond. No.                     3.17e+23
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is  4e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
## get pvalues from model result
pvalues =result.pvalues
pvalues
# Out:
# certification_G                        8.887230e-01
# certification_MISSING                 4.376537e-163
# certification_NC-17                    3.207879e-16
# certification_NR                       4.044334e-05
# certification_PG                       3.286438e-02
#                                           ...
# ProdComp_Village Roadshow Pictures     2.272321e-01
# ProdComp_Walt Disney Pictures          1.506774e-06
# ProdComp_Warner Bros. Pictures         3.966927e-01
# ProdComp_Working Title Films           9.822767e-01
# const                                  5.373602e-03
# Length: 87, dtype: float64

# %%
## Check for p-values that are >.05
pvalues[pvalues>.05]
# Out:
# certification_G                       0.888723
# adult                                 0.079532
# budget                                0.549521
# Genre_Music                           0.817392
# Genre_Action                          0.674713
# Genre_Crime                           0.505094
# Genre_Adventure                       0.105024
# Genre_Animation                       0.064883
# Genre_Horror                          0.206755
# Genre_Thriller                        0.994575
# Genre_History                         0.699287
# Genre_Family                          0.519022
# Genre_War                             0.262201
# Genre_TV Movie                        0.788387
# Genre_Documentary                     0.385385
# ProdComp_Amblin Entertainment         0.313008
# ProdComp_BBC Films                    0.668036
# ProdComp_Blumhouse Productions        0.053903
# ProdComp_Canal+                       0.567084
# ProdComp_Ciné+                        0.419527
# ProdComp_Dimension Films              0.482089
# ProdComp_DreamWorks Animation         0.117513
# ProdComp_Film4 Productions            0.240333
# ProdComp_Focus Features               0.917556
# ProdComp_Fox 2000 Pictures            0.219181
# ProdComp_Fox Searchlight Pictures     0.586497
# ProdComp_Ingenious Media              0.124261
# ProdComp_Legendary Pictures           0.291284
# ProdComp_Lionsgate                    0.648469
# ProdComp_Metro-Goldwyn-Mayer          0.772647
# ProdComp_Millennium Films             0.091760
# ProdComp_NPV Entertainment            0.496548
# ProdComp_Original Film                0.631783
# ProdComp_Relativity Media             0.069082
# ProdComp_Revolution Studios           0.186698
# ProdComp_Scott Free Productions       0.079554
# ProdComp_Sony Pictures                0.146339
# ProdComp_Spyglass Entertainment       0.530626
# ProdComp_StudioCanal                  0.194336
# ProdComp_TF1 Films Production         0.835653
# ProdComp_TSG Entertainment            0.983316
# ProdComp_The Weinstein Company        0.738783
# ProdComp_Village Roadshow Pictures    0.227232
# ProdComp_Warner Bros. Pictures        0.396693
# ProdComp_Working Title Films          0.982277
# dtype: float64

# %% [markdown]
# ### Removing features - based on p-values

# %%
## Get list of ALL genre columns to see how many are sig
genre_cols
# Out:
# ['Genre_Comedy',
#  'Genre_Music',
#  'Genre_Romance',
#  'Genre_Science Fiction',
#  'Genre_Drama',
#  'Genre_Action',
#  'Genre_Crime',
#  'Genre_Adventure',
#  'Genre_Animation',
#  'Genre_Fantasy',
#  'Genre_Horror',
#  'Genre_Thriller',
#  'Genre_History',
#  'Genre_Family',
#  'Genre_Mystery',
#  'Genre_Western',
#  'Genre_War',
#  'Genre_TV Movie',
#  'Genre_Documentary']

# %%
## save just genre pvalues
genre_pvals = pvalues[genre_cols]
genre_pvals
# Out:
# Genre_Comedy             9.717125e-04
# Genre_Music              8.173923e-01
# Genre_Romance            4.554800e-03
# Genre_Science Fiction    1.535886e-20
# Genre_Drama              2.632071e-04
# Genre_Action             6.747129e-01
# Genre_Crime              5.050945e-01
# Genre_Adventure          1.050240e-01
# Genre_Animation          6.488281e-02
# Genre_Fantasy            9.578592e-07
# Genre_Horror             2.067551e-01
# Genre_Thriller           9.945753e-01
# Genre_History            6.992869e-01
# Genre_Family             5.190218e-01
# Genre_Mystery            4.265509e-02
# Genre_Western            7.223807e-03
# Genre_War                2.622011e-01
# Genre_TV Movie           7.883865e-01
# Genre_Documentary        3.853855e-01
# dtype: float64

# %%
(genre_pvals>.05).sum() /len(genre_pvals)
# Out:
# 0.631578947368421

# %%
## calc what % are insig?
len(genre_pvals>.05)/len(genre_pvals)
# Out:
# 1.0

# %%
comp_cols = [c for c in df_clean_iqr if c.startswith('ProdComp')]

# %%
comp_cols
# Out:
# ['ProdComp_20th Century Fox',
#  'ProdComp_Amblin Entertainment',
#  'ProdComp_BBC Films',
#  'ProdComp_Blumhouse Productions',
#  'ProdComp_CJ Entertainment',
#  'ProdComp_Canal+',
#  'ProdComp_Ciné+',
#  'ProdComp_Columbia Pictures',
#  'ProdComp_Dimension Films',
#  'ProdComp_DreamWorks Animation',
#  'ProdComp_DreamWorks Pictures',
#  'ProdComp_Dune Entertainment',
#  'ProdComp_Epsilon Motion Pictures',
#  'ProdComp_EuropaCorp',
#  'ProdComp_Film4 Productions',
#  'ProdComp_Focus Features',
#  'ProdComp_Fox 2000 Pictures',
#  'ProdComp_Fox Searchlight Pictures',
#  'ProdComp_France 2 Cinéma',
#  'ProdComp_Ingenious Media',
#  'ProdComp_Legendary Pictures',
#  'ProdComp_Lionsgate',
#  'ProdComp_MISSING',
#  'ProdComp_Metro-Goldwyn-Mayer',
#  'ProdComp_Millennium Films',
#  'ProdComp_Miramax',
#  'ProdComp_NPV Entertainment',
#  'ProdComp_New Line Cinema',
#  'ProdComp_New Regency Pictures',
#  'ProdComp_Original Film',
#  'ProdComp_Paramount',
#  'ProdComp_Regency Enterprises',
#  'ProdComp_Relativity Media',
#  'ProdComp_Revolution Studios',
#  'ProdComp_Scott Free Productions',
#  'ProdComp_Scott Rudin Productions',
#  'ProdComp_Screen Gems',
#  'ProdComp_Sony Pictures',
#  'ProdComp_Spyglass Entertainment',
#  'ProdComp_StudioCanal',
#  'ProdComp_Summit Entertainment',
#  'ProdComp_TF1 Films Production',
#  'ProdComp_TSG Entertainment',
#  'ProdComp_The Weinstein Company',
#  'ProdComp_Touchstone Pictures',
#  'ProdComp_Universal Pictures',
#  'ProdComp_Village Roadshow Pictures',
#  'ProdComp_Walt Disney Pictures',
#  'ProdComp_Warner Bros. Pictures',
#  'ProdComp_Working Title Films']

# %%
## Get list of ALL prod_comp columns to see how many are sig
comp_pvals = pvalues[comp_cols]
(comp_pvals>.05).sum()
# Out:
# 30

# %%
len(comp_pvals>.05)/len(comp_pvals)
# Out:
# 1.0

# %% [markdown]
# ## Model 4

# %%
df_clean_iqr = df_clean_iqr.drop(columns=[*genre_cols, *comp_cols])
df_clean_iqr
# Out:
#        adult  belongs_to_collection      budget  popularity      revenue  \
# 3        0.0                  False    150000.0      20.312   12854953.0
# 10       0.0                  False    120000.0       7.950      14904.0
# 12       0.0                   True  45000000.0      45.071  224834564.0
# 15       0.0                  False   8000000.0       9.533     105983.0
# 18       0.0                  False  75000000.0      15.257   36754634.0
# ...      ...                    ...         ...         ...          ...
# 64826    0.0                  False  15000000.0      35.140   18192220.0
# 64862    0.0                  False  27500000.0      52.226   19046191.0
# 64869    0.0                   True  11000000.0      18.594    3189418.0
# 64957    0.0                  False  26000000.0      19.389    6416063.0
# 64969    0.0                  False  17516235.0      14.901   19002036.0
#
#        runtime  vote_average  vote_count certification    year  month   day
# 3         99.0           8.1      1859.0            PG  2000.0    9.0  29.0
# 10        87.0           5.5        40.0             R  2002.0    4.0  26.0
# 12        84.0           6.7      3991.0             G  2000.0    6.0  21.0
# 15       122.0           5.9       246.0             R  2000.0    2.0   9.0
# 18        94.0           6.6       846.0            PG  2000.0    6.0  16.0
# ...        ...           ...         ...           ...     ...    ...   ...
# 64826    130.0           6.5      1083.0             R  2021.0    7.0  29.0
# 64862    137.0           6.4       160.0         PG-13  2021.0    9.0  24.0
# 64869    133.0           6.2       290.0           NaN  2021.0   12.0  16.0
# 64957    126.0           7.4      1011.0           NaN  2021.0    2.0  12.0
# 64969    120.0           6.9       455.0           NaN  2021.0    7.0  21.0
#
# [4903 rows x 12 columns]

# %%
## Use our function to make new x,y vars
X_train_df, y_train, X_test_df, y_test = get_train_test_split(df_clean_iqr)

## instantiate an OLS model WITH the training data.
model = sm.OLS(y_train, X_train_df)

## Fit the model and view the summary
result = model.fit()
evaluate_ols(result, X_train_df, y_train)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                revenue   R-squared:                       0.592
# Model:                            OLS   Adj. R-squared:                  0.591
# Method:                 Least Squares   F-statistic:                     332.5
# Date:                Fri, 20 May 2022   Prob (F-statistic):               0.00
# Time:                        11:06:55   Log-Likelihood:                -68805.
# No. Observations:                3677   AIC:                         1.376e+05
# Df Residuals:                    3660   BIC:                         1.377e+05
# Df Model:                          16
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# certification_G       -5.112e+06   3.25e+07     -0.157      0.875   -6.89e+07    5.87e+07
# certification_MISSING     0.8171      0.025     32.215      0.000       0.767       0.867
# certification_NC-17    4.882e+05   6.31e+04      7.733      0.000    3.64e+05    6.12e+05
# certification_NR       8.461e+04   2.74e+04      3.090      0.002    3.09e+04    1.38e+05
# certification_PG       5.212e+05   4.98e+05      1.047      0.295   -4.54e+05     1.5e+06
# certification_PG-13    1.181e+04    464.445     25.427      0.000    1.09e+04    1.27e+04
# certification_R       -4.664e+05   9.44e+04     -4.941      0.000   -6.52e+05   -2.81e+05
# adult                 -2.729e+05   1.55e+05     -1.766      0.077   -5.76e+05       3e+04
# budget                -1.227e+04   6.22e+04     -0.197      0.843   -1.34e+05     1.1e+05
# popularity             1.344e+08   2.39e+07      5.631      0.000    8.76e+07    1.81e+08
# runtime                1.126e+08    2.4e+07      4.701      0.000    6.56e+07     1.6e+08
# vote_average           1.064e+08   2.52e+07      4.222      0.000     5.7e+07    1.56e+08
# vote_count             1.113e+08    2.4e+07      4.636      0.000    6.42e+07    1.58e+08
# year                   1.208e+08   2.38e+07      5.081      0.000    7.42e+07    1.67e+08
# month                  1.198e+08   2.36e+07      5.067      0.000    7.34e+07    1.66e+08
# day                    1.066e+08   2.36e+07      4.510      0.000    6.02e+07    1.53e+08
# belongs_to_collection  1.845e+07   1.52e+06     12.154      0.000    1.55e+07    2.14e+07
# const                  8.119e+08   1.66e+08      4.894      0.000    4.87e+08    1.14e+09
# ==============================================================================
# Omnibus:                      751.007   Durbin-Watson:                   1.989
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3233.273
# Skew:                           0.934   Prob(JB):                         0.00
# Kurtosis:                       7.197   Cond. No.                     1.85e+23
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.24e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# ### Addressing Multicollinearity

# %%
## Calculating the mask to hide the upper-right of the triangle
corr = X_train_df.corr().abs()

mask = np.triu(np.ones_like(corr))

plt.figure(figsize=(25,25))
sns.heatmap(corr,square=True, cmap='Reds', annot=True, mask=mask);

# %% [markdown]
# ### Variance Inflation Factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
 
# separate just x-data and subtract mean
features = X_train_df -  X_train_df.mean()

features
# Out:
#        certification_G  certification_MISSING  certification_NC-17  \
# 50852        -0.000272          -2.040330e+07            -5.896697
# 15159        -0.000272          -2.240329e+07             1.408303
# 19599        -0.000272          -1.440330e+07           -12.366697
# 31419        -0.000272          -1.750330e+07           -13.915697
# 51568        -0.000272          -2.191706e+07           -13.922697
# ...                ...                    ...                  ...
# 34464        -0.000272           2.596702e+06             8.304303
# 37310        -0.000272          -1.910330e+07            -1.431697
# 5134         -0.000272           3.959670e+07            -4.153697
# 18976        -0.000272          -1.740330e+07             7.318303
# 16973        -0.000272          -1.640330e+07           -10.686697
#
#        certification_NR  certification_PG  certification_PG-13  \
# 50852        -11.494425          0.804732          -844.926299
# 15159         -8.494425         -0.195268          -838.926299
# 19599         57.505575         -0.695268          -995.926299
# 31419         28.505575         -1.695268         -1023.926299
# 51568         56.505575          3.104732         -1045.926299
# ...                 ...               ...                  ...
# 34464         -8.494425          0.504732          -718.926299
# 37310        -25.494425         -0.995268           143.073701
# 5134          16.505575         -0.395268          -556.926299
# 18976        -18.494425         -0.795268          -581.926299
# 16973         29.505575          0.804732          -964.926299
#
#        certification_R     adult     budget  popularity   runtime  \
# 50852         8.945777 -0.724796  -7.156676   -0.015502 -0.251836
# 15159        -2.054223 -0.724796  -0.156676   -0.015502 -0.251836
# 19599        -0.054223  4.275204  11.843324   -0.015502  0.748164
# 31419         3.945777  2.275204  -2.156676   -0.015502  0.748164
# 51568         8.945777  1.275204   5.843324   -0.015502  0.748164
# ...                ...       ...        ...         ...       ...
# 34464         4.945777  3.275204  15.843324   -0.015502  0.748164
# 37310         5.945777 -5.724796  13.843324   -0.015502 -0.251836
# 5134         -8.054223 -4.724796   7.843324   -0.015502 -0.251836
# 18976        -0.054223 -1.724796  -3.156676   -0.015502 -0.251836
# 16973        -1.054223 -3.724796  -3.156676   -0.015502 -0.251836
#
#        vote_average  vote_count      year     month       day  \
# 50852     -0.003264   -0.029372 -0.085124  0.736742 -0.351645
# 15159     -0.003264   -0.029372 -0.085124 -0.263258  0.648355
# 19599     -0.003264   -0.029372 -0.085124 -0.263258 -0.351645
# 31419     -0.003264   -0.029372 -0.085124 -0.263258 -0.351645
# 51568     -0.003264   -0.029372 -0.085124 -0.263258 -0.351645
# ...             ...         ...       ...       ...       ...
# 34464     -0.003264   -0.029372 -0.085124 -0.263258 -0.351645
# 37310     -0.003264   -0.029372 -0.085124  0.736742 -0.351645
# 5134      -0.003264   -0.029372 -0.085124 -0.263258  0.648355
# 18976     -0.003264   -0.029372 -0.085124 -0.263258  0.648355
# 16973     -0.003264   -0.029372 -0.085124 -0.263258  0.648355
#
#        belongs_to_collection  const
# 50852              -0.159913    0.0
# 15159              -0.159913    0.0
# 19599              -0.159913    0.0
# 31419               0.840087    0.0
# 51568              -0.159913    0.0
# ...                      ...    ...
# 34464              -0.159913    0.0
# 37310              -0.159913    0.0
# 5134               -0.159913    0.0
# 18976               0.840087    0.0
# 16973              -0.159913    0.0
#
# [3677 rows x 18 columns]

# %%
# create a list of VIF scores for each feature in features.
vif_scores = [variance_inflation_factor(features.values, i) for i in range(len(features.columns))]

# create a new dataframe to hold the VIF scores 
VIF = pd.Series(vif_scores, index=features.columns)
VIF
# Out:
# /Users/oleksandraaliyeva/opt/anaconda3/envs/dojo-env/lib/python3.7/site-packages/statsmodels/stats/outliers_influence.py:195: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# /Users/oleksandraaliyeva/opt/anaconda3/envs/dojo-env/lib/python3.7/site-packages/statsmodels/regression/linear_model.py:1738: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.uncentered_tss
# certification_G          1.003184
# certification_MISSING    1.464773
# certification_NC-17      1.904009
# certification_NR         1.168696
# certification_PG         1.210696
# certification_PG-13      1.741385
# certification_R          1.138070
# adult                    1.006342
# budget                   1.008528
# popularity                    inf
# runtime                       inf
# vote_average                  inf
# vote_count                    inf
# year                          inf
# month                         inf
# day                           inf
# belongs_to_collection    1.080465
# const                         NaN
# dtype: float64

# %%
## Visualize Coefficients
ax = result.params.sort_values().plot(kind='barh')
ax.axvline()

# %% [markdown]
# ### Compare to Alternative Regressors

# %%
from sklearn.ensemble import RandomForestRegressor
X_train_df, y_train, X_test_df, y_test = get_train_test_split(df)

reg = RandomForestRegressor(verbose=1,random_state=42)
reg.fit(X_train_df, y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.8s finished
# RandomForestRegressor(random_state=42, verbose=1)

# %%
## Get train data performance from skearn to confirm matches OLS
y_hat_train = reg.predict(X_train_df)
print(f'Training R^2: {r2_score(y_train, y_hat_train):.3f}')

## Get test data performance
y_hat_test = reg.predict(X_test_df)
print(f'Testing R^2: {r2_score(y_test, y_hat_test):.3f}')
# Out:
# Training R^2: 0.975
# Testing R^2: 0.795
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished

# %%
evaluate_ols(reg, X_train_df, y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.1s finished

# %%
importances = pd.Series(reg.feature_importances_, index=X_train_df.columns)
importances.sort_values().tail(25).plot(kind='barh',figsize=(6,10))
